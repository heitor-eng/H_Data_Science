# %% [markdown]
# <a href="https://colab.research.google.com/github/heitor-eng/H_Data_Science/blob/master/Data_Science_Projeto_2_Covid19_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Understand the Covid - 19 situation around the World and Brazil throughout data visualization
#
# This project proposes to show how to take a vast and complex dataset and create graphs that will translate the meaning of the dataset into figures, in this case into graphics. And to make that happen, I am inspired by the ideas of the book [Storytelling with Data: A Data Visualization Guide for Business Professionals](https://www.amazon.com.br/Storytelling-Data-Visualization-Business-Professionals/dp/1119002257/ref=pd_bxgy_img_2/146-1595837-0433809?pd_rd_w=UWIh4&pf_rd_p=4a943320-02ab-4775-ad7a-eaf57d00a244&pf_rd_r=A53HPMNAGVE7QS07AA0K&pd_rd_r=eed0f3cc-beba-43b4-a367-e818cca88fec&pd_rd_wg=ZhgsO&pd_rd_i=1119002257&psc=1) by Cole Nussbaumer Knaflic.
#
# <p align=center>
# <img src = "https://github.com/heitor-eng/H_Data_Science/blob/master/Imagens/statistic-1564428_1920.png?raw=true" width = "50%">
# </p>
#
# The dataset used here is from the GitHub page of [Our World in Data](https://github.com/owid/covid-19-data). The repository in which new data is added daily with further information of COVID 19 in the world, and for that reason, the date 2021-12-08 was the stop point for new pieces of information for this project.
#
# To understand more about the data set, click on [READ ME](https://github.com/owid/covid-19-data/blob/master/public/data/README.md).
#
#
# And now let's talk about what is COVID-19 and understand the reasons to coronavirus has become a pandemic problem.

# %% [markdown]
# ## What do you know about the coronavirus disease (COVID-19) that is causing a health emergency? 🦠
#
# According to the web page from the [World Health Organization](https://www.who.int/health-topics/coronavirus#tab=tab_1):
#
# "Coronavirus disease (COVID-19) is an infectious disease caused by the SARS-CoV-2 virus. And can affects different people in different ways. Most infected people will develop mild to moderate illness and recover without hospitalization. However, some will become seriously ill and require medical attention. Older people and those with underlying medical conditions like cardiovascular disease, diabetes, chronic respiratory disease, or cancer are more likely to develop serious illness. **Anyone can get sick with COVID-19 and become seriously ill or die at any age**."
#
# <p align=center>
# <img src = "https://github.com/heitor-eng/H_Data_Science/blob/master/Imagens/pexels-cdc-3992933.jpg?raw=true" width = "50%">
# </p>
#
# **The Symptoms**
#
# * Most common symptoms:
#   * fever
#   * cough
#   * tiredness
#   * loss of taste or smell.
#
# * Less common symptoms:
#   * sore throat
#   * headache
#   * aches and pains
#   * diarrhoea
#   * a rash on skin, or discolouration of fingers or toes
#   * red or irritated eyes.
#
# * Serious symptoms:
#
#   * difficulty breathing or shortness of breath
#   * loss of speech or mobility, or confusion
#   * chest pain.
#
# On average it takes 5–6 days from when someone is infected with the virus for symptoms to show, however it can take up to 14 days.
#
# Youtube Channel from the [WHO](https://www.youtube.com/watch?v=i0ZabxXmH4Y).
#
# ---
# ## Why has Coronavirus become a threat to the world?
# Because of some factors, like:
#
# * The velocity of the spread of the SARS-CoV-2 virus is fast
# * We didn't know that much about the virus
# * Several people have symptoms at the same time
# * We didn't have vaccines
# * High mutation rate
#
# These were the main reasons Coronavirus has become a threat in today's world.

# %% [markdown]
# ## Our World in Data - Dataset
#
# The dataset has a lot of variables, columns, but we can see the main topics are:
#
# > Confirmed cases
#
# > Confirmed deaths
#
# > Excess of mortality
#
# > Hospital & UCI
#
# > Tests & positivity
#
# > Vaccinations
#
# > Others
#
#
# So without further ado, let's go to the dataset and do the work.
#
# ## ETL - Extract, Transform and Load:

# %%
# Calling the libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# configuring the graphics
# %matplotlib inline
sns.set_style()

# %%
# DataFrame until 01/12/2021
PATH = "https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv"
df_w = pd.read_csv(PATH)
df_w = df_w[df_w.date <= '2021-12-08']

# %%
# DataFrame
print("The DataFrame has:",
      "\nNumber of rows:",df_w.shape[0],
      "\nand",df_w.shape[1], "number of columns"
      )
# Out:
# The DataFrame has:
# Number of rows: 146037
# and 67 number of columns

# %%
# The first five data
df_w.head()
# Out:
#   iso_code continent  ... excess_mortality excess_mortality_cumulative_per_million
# 0      AFG      Asia  ...              NaN                                     NaN
# 1      AFG      Asia  ...              NaN                                     NaN
# 2      AFG      Asia  ...              NaN                                     NaN
# 3      AFG      Asia  ...              NaN                                     NaN
# 4      AFG      Asia  ...              NaN                                     NaN
#
# [5 rows x 67 columns]

# %%
# the last five
df_w.tail()
# Out:
#        iso_code  ... excess_mortality_cumulative_per_million
# 150371      ZWE  ...                                     NaN
# 150372      ZWE  ...                                     NaN
# 150373      ZWE  ...                                     NaN
# 150374      ZWE  ...                                     NaN
# 150375      ZWE  ...                                     NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# **Extraction** of the variables:
#
# Now is time to know which are all the variables the dataset has.

# %%
df_w.columns.to_list()
# Out:
# ['iso_code',
#  'continent',
#  'location',
#  'date',
#  'total_cases',
#  'new_cases',
#  'new_cases_smoothed',
#  'total_deaths',
#  'new_deaths',
#  'new_deaths_smoothed',
#  'total_cases_per_million',
#  'new_cases_per_million',
#  'new_cases_smoothed_per_million',
#  'total_deaths_per_million',
#  'new_deaths_per_million',
#  'new_deaths_smoothed_per_million',
#  'reproduction_rate',
#  'icu_patients',
#  'icu_patients_per_million',
#  'hosp_patients',
#  'hosp_patients_per_million',
#  'weekly_icu_admissions',
#  'weekly_icu_admissions_per_million',
#  'weekly_hosp_admissions',
#  'weekly_hosp_admissions_per_million',
#  'new_tests',
#  'total_tests',
#  'total_tests_per_thousand',
#  'new_tests_per_thousand',
#  'new_tests_smoothed',
#  'new_tests_smoothed_per_thousand',
#  'positive_rate',
#  'tests_per_case',
#  'tests_units',
#  'total_vaccinations',
#  'people_vaccinated',
#  'people_fully_vaccinated',
#  'total_boosters',
#  'new_vaccinations',
# ...

# %% [markdown]
# > It understands the type of the variables with `dtypes` to see if isn't any problem in this part of the data frame.

# %%
df_w.dtypes
# Out:
# iso_code                                    object
# continent                                   object
# location                                    object
# date                                        object
# total_cases                                float64
#                                             ...
# human_development_index                    float64
# excess_mortality_cumulative_absolute       float64
# excess_mortality_cumulative                float64
# excess_mortality                           float64
# excess_mortality_cumulative_per_million    float64
# Length: 67, dtype: object

# %% [markdown]
# The code above shows the column `date` as an object type. Therefore, it can be a problem when plotting graphs using the column `date`.
# So my next move will be to change this column to the `DateTime` type.

# %%
# Transform the variable date into a datetime type
df_w['date'] = pd.to_datetime(df_w['date'])

# %%
# The type of the column date 
df_w.date
# Out:
# 0        2020-02-24
# 1        2020-02-25
# 2        2020-02-26
# 3        2020-02-27
# 4        2020-02-28
#             ...
# 150371   2021-12-04
# 150372   2021-12-05
# 150373   2021-12-06
# 150374   2021-12-07
# 150375   2021-12-08
# Name: date, Length: 146037, dtype: datetime64[ns]

# %% [markdown]
# **The Nan-values or the empty values**
#
# This is another step to do when you are working with data set builds from others.

# %%
# Understanding the percentage of Nan values in the data set
round((df_w.isnull().sum()/df_w.shape[0]).sort_values(ascending=False),3)
# Out:
# weekly_icu_admissions                      0.972
# weekly_icu_admissions_per_million          0.972
# excess_mortality_cumulative_per_million    0.964
# excess_mortality                           0.964
# excess_mortality_cumulative_absolute       0.964
#                                            ...
# total_cases                                0.018
# population                                 0.007
# date                                       0.000
# location                                   0.000
# iso_code                                   0.000
# Length: 67, dtype: float64

# %% [markdown]
# For this data set, all the **ETL** work has finished. Now it is time to start the exploratory analysis work.
#
#
# ---
#
#
# ##EDA - Exploratory Data Analysis
#
# EDA - Exploratory Data Analysis
#
# To start the exploratory analysis of the dataset, let's look at the graph of two variables, the  `new_cases_smoothed` and the `new_deaths_smoothed`. These two variables can show the growth or decay of new cases and new deaths.
#
# The reason for that is because these two variables are calculated through the formula of the **sample moving average** of these cases during seven days, as shown in the procedure below:
#
# $$SMA = \frac{d_1 + d_2 + d_3 + ... + d_n}{n}$$
#
# **Where:**
#
# > **d** = The total of new cases or new deaths of the period *n*
#
# > **n** = The number of total periods, for this case is 7

# %%
# Configuring the style
sns.set_style('ticks')

# build the figure
fig, (ax1,ax2) =plt.subplots(nrows= 2,ncols = 1, figsize=(14,14))

# variable n_cases_smooth
n_cases_smooth = (df_w.loc[df_w.location =="World", ['date','new_cases_smoothed']].reset_index(drop=True))

# Graph about the number of cases smoothed
sns.lineplot(x='date',y = 'new_cases_smoothed', data=n_cases_smooth, ci = None, linewidth=5, color = 'Grey', ax = ax1)
ax1.set_title('\n Moving Average Smoothed of the number of New Cases of COVID-19 in the World \n', color = 'Grey', size = 20,loc = 'left')
ax1.set_xlabel([],color = 'white')
ax1.set_ylabel([],color = 'white')
ax1.yaxis.set_ticklabels(['0','0','200k','400k','800k','1M'])

# variable about the number of new deaths smoothed
n_deaths_smooth =(df_w.loc[df_w.location =='World', ['date','new_deaths_smoothed']].reset_index(drop=True))

# Graph about the new deaths
sns.lineplot(x='date',y = 'new_deaths_smoothed', data=n_deaths_smooth, ci = None, linewidth=5, color = 'DarkBlue', ax = ax2)
ax2.set_title('\n Moving Average Smoothed of the number of New Deaths of COVID-19 in the World \n', color = 'Grey', size = 20,loc = 'left')
ax2.set_xlabel([],color = 'white')
ax2.set_ylabel([],color = 'white')
ax2.yaxis.set_ticklabels(['0','0','2k','4k','6k','8k','10k','12k','14k'])

sns.despine()
plt.tight_layout()

# %% [markdown]
# **At first sight**
#
# The interpretation of these two graphs are:
# * The number of the variable `new_cases` is increasing again
# * The difference between the number of `new_cases` and `new_deaths` is quite different
# * The number of the variable `new_deaths` seems to be starting to maintain a pattern, without many peaks and valleys
#
# These three points are what we can see through these graphs.
#
# Done, let's continue the analysis and search for the five nations with the most `total_cases` of COVID-19 and `total_deaths` attributed to COVID-19.
#
# ***Total Cases:***

# %%
# The top 5 countries with total cases
top_5t = (df_w.loc[(df_w.date == '2021-12-01') & df_w.continent.notnull(), [ 'iso_code','location', 'total_cases']].sort_values
          (by='total_cases',ascending = False).reset_index(drop=True)[:5])

print("Table 1 - The five nations with the highest numbers of total cases:\n")
top_5t
# Out:
# Table 1 - The five nations with the highest numbers of total cases:
#   iso_code        location  total_cases
# 0      USA   United States   48699210.0
# 1      IND           India   34606541.0
# 2      BRA          Brazil   22112425.0
# 3      GBR  United Kingdom   10294408.0
# 4      RUS          Russia    9500836.0

# %% [markdown]
# ***Building a graph for the five countries with the most cases of Covid -19***

# %%
# The top 5 cases in the World

# Define the style
sns.set_style('ticks')
fig, ax = plt.subplots(figsize=(14,8))

# Build the variable for the top 5 countries
tc_5 = (df_w.loc[(df_w.date =='2021-12-08') & df_w.continent.notnull()].sort_values(by = 'total_cases', ascending = False)[:5].copy())

# Calling the plot
bar_plot = sns.barplot(x = 'total_cases' , y = 'location' ,data = tc_5, orient = 'h',ax = ax, color = "#357599")

# Customizing the plot
for p in bar_plot.patches:
    width=int(p.get_width())
    plt.text(p.get_width(), p.get_y()+0.55*p.get_height(),
            '{}'.format(width),
             ha='right', va='center', color='white', size=16, fontweight='bold')
 
ax.set_title('The five countries with the highest numbers of total cases\n', loc='left', size=22, color='DarkSlateGray')
ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')
ax.set_xticklabels([],color = 'whiite')
ax.set_yticklabels(["EUA","IND","BRA","GBR",'RUS'],{'fontsize': 16, 
 'verticalalignment': 'baseline'})
sns.despine(left=True, bottom=True)


plt.tight_layout()

# %% [markdown]
# ***Total Deaths***

# %%
# Finding the five countries with the most number of total_deaths
t5_d =(df_w.loc[(df_w.date == '2021-12-08') & df_w.continent.notnull(),
                ['iso_code','location','total_deaths']].sort_values(by = 'total_deaths', ascending = False).reset_index(drop=True)[:5])

print("Table 2 -The five nations with the highest numbers of total deaths:\n")
t5_d
# Out:
# Table 2 -The five nations with the highest numbers of total deaths:
#   iso_code       location  total_deaths
# 0      USA  United States      794347.0
# 1      BRA         Brazil      616533.0
# 2      IND          India      474111.0
# 3      MEX         Mexico      295602.0
# 4      RUS         Russia      279280.0

# %%
# Graph for the five countries with the highest number of deaths
sns.set_style('white')
fig, ax = plt.subplots(figsize=(12,8))

# The variable td_5 will be the values for the data at the bar plot
td_5 = (df_w.loc[(df_w.date == '2021-12-08') & df_w.continent.notnull()].sort_values(by ='total_deaths', ascending = False)[:5]).copy()

# the barplot
dplot = sns.barplot(x = 'location', y = 'total_deaths', data = td_5, ax = ax, color = 'Orange')

# Customizing the plot
for i in dplot.patches:
    dplot.annotate(int(i.get_height()),
                   (i.get_x() + i.get_width()/2, i.get_height()),
                   ha = 'center',
                   va = 'center',
                   size = 15,
                   color = 'white',
                   fontweight= 'bold',
                   xytext = (0,-15),
                   textcoords = 'offset points'
                   )
    
ax.set_title(" The five countries with the highest number of deaths", loc = 'left', size = 20, color = 'DarkSlateGray') 
ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')
ax.set_xticklabels(["EUA","IND","BRA","MEX",'RUS'],{'fontsize': 16})
ax.set_yticklabels([],color = 'white')
sns.despine(left=True, bottom=True)


plt.tight_layout()

# %% [markdown]
# ### **What do the graphs show?**
#
# As we can see through the graphs, the most significant countries with the highest numbers of deaths are the countries with more people, and the countries with more income can do more tests than other nations, with the proportion respect of income and area. Because the **GRB** appears at the fourth in most cases, but for the number of `total_deaths`, we have **MEX**.
#
# Something we have at projects like this is the understanding of the situation for each country, and for this graphs are:
#
# * Take measures to slow down the transmission of the virus by blocking and restricting the number of people indoors. Each nation has a way of enforcing measures to stop or reduce the menssage
#
# * The second one is the area of which country, as we know, the **GRB** is an Island, while the other five countries for the graph about `total_cases` have a continental proportion. So for these nations, the number of deaths will be more, and the money to do the test will be greater than for **GRB**
#
# * Countries with more income were able to have access to the vaccines first
#
#
# These three points are essential to be taken into account when analyzing the situation of covid-19 in each place in the world.
#
# ###**Moving Forward**
# Now let's look at two variables that help track how fast the virus is spreading.
#
# **Reproduction Rate (R0)** :
#
# It is the rate that shows how fast is the spread of the vírus at the local.
# > "If the population average R0 is greater than 1, the infection will spread exponentially. If the R0 is less than 1, the infection will only spread slowly, and eventually disappear. The higher the value of R0, the faster an epidemic will progress."  By [Oxford Brasil](https://oxfordbrazilebm.com/index.php/quando-isso-acabara-uma-introducao-aos-numeros-de-reproducao-viral-r0-e-re/).
#
# To understand the calculus, click on [Tracking R of Covid-19](https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0244474).

# %%
# The ten countries with the worst reproduction rate 
Repro_r =(df_w.loc[(df_w.date == '2021-12-08') & df_w.continent.notnull(),
                ['location','reproduction_rate']].sort_values(by = 'reproduction_rate', ascending = False).reset_index(drop=True)[:10])

print("Table 3 -The ten countries with the worst reproduction rate:\n")
Repro_r
# Out:
# Table 3 -The ten countries with the worst reproduction rate:
#        location  reproduction_rate
# 0      Eswatini               3.23
# 1    Mozambique               2.69
# 2        Zambia               2.38
# 3        Malawi               2.32
# 4      Zimbabwe               2.30
# 5  South Africa               1.78
# 6       Namibia               1.71
# 7         Kenya               1.66
# 8         Spain               1.65
# 9        Rwanda               1.65

# %%
# The ten nations with the better R0 
Repro_m =(df_w.loc[(df_w.date == '2021-12-01') & df_w.continent.notnull(),
                ['location','reproduction_rate']].sort_values(by = 'reproduction_rate').reset_index(drop=True)[:10])

print("Table 4 -The ten nations with the better R0:\n")
Repro_m
# Out:
# Table 4 -The ten nations with the better R0:
#                    location  reproduction_rate
# 0                Tajikistan              -0.00
# 1              Burkina Faso               0.02
# 2                      Chad               0.04
# 3  Central African Republic               0.13
# 4     Sao Tome and Principe               0.14
# 5              Sierra Leone               0.17
# 6               El Salvador               0.30
# 7                   Liberia               0.32
# 8                Madagascar               0.37
# 9                  Tanzania               0.39

# %% [markdown]
# **Tests**
#
# The number of tests carried out will allow the health centers in each country to understand how the situation is for each region.
#
# So to build the analyses, the variables will be `total_test` and now let's look at the ten-country which have the highest number of tests so far.

# %%
# The ten countries with more tests done
test =(df_w.loc[(df_w.date == '2021-12-01') & df_w.continent.notnull(),
                ['location','total_tests']].sort_values(by = 'total_tests', ascending = False).reset_index(drop=True)[:10])

print("Table 5 - The top ten countries which lead the numbers of total tests:\n")
test
# Out:
# Table 5 - The top ten countries which lead the numbers of total tests:
#                location  total_tests
# 0         United States  671702737.0
# 1                 India  642412315.0
# 2        United Kingdom  330168933.0
# 3                 Italy  119905510.0
# 4               Austria  111071336.0
# 5                Turkey  108327390.0
# 6  United Arab Emirates  101952969.0
# 7                Brazil   65380088.0
# 8                Canada   48895595.0
# 9             Australia   48083139.0

# %% [markdown]
# **From these two tables,  we can see that:**
#
# * Countries that are larger and have a higher population density are testing more than the others and need to do that because of the way the vírus act.
#
# * The nations with more income can do more tests than other countries.
#
# ###With the idea of using graphs to improve the analysis, we have the graphic below:

# %%
# Graph for the seve  countries with the highest number of tests
sns.set_style('white')
fig, ax = plt.subplots(figsize=(12,8))

# The variable td_5 will be the values for the data at the bar plot
td_7 = (df_w.loc[(df_w.date == '2021-12-08') & df_w.continent.notnull()].sort_values(by ='total_tests', ascending = False)[:7]).copy()

# the barplot
dplot = sns.barplot(x = 'location', y = 'total_tests', data = td_7, ax = ax, color = 'Orange')

# Customizing the plot
for i in dplot.patches:
    dplot.annotate(int(i.get_height()),
                   (i.get_x() + i.get_width()/2, i.get_height()),
                   ha = 'center',
                   va = 'center',
                   size = 14,
                   color = 'gray',
                   fontweight='bold',
                   xytext = (0,15),
                   textcoords = 'offset points'
                   )
    
ax.set_title(" The seven nations with more number tests done\n", loc = 'left', size = 20, color = 'DarkSlateGray') 
ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')
ax.set_xticklabels(["EUA","IND","GRB","ITA","AUT","TUR","BRA"],{'fontsize': 16})
ax.set_yticklabels([],color = 'white')
sns.despine(left=True, bottom=True)


plt.tight_layout()

# %% [markdown]
# **Looking at the graph**, maybe nothing changes compared to the charts for total cases and deaths, but here we don't have **Russia**, and even in Table 5, this country doesn't appear in the ten countries with more tests done.
#
# So without the graph, maybe this is some point we wouldn't notice.

# %% [markdown]
# ## Vaccines
#
# In this section, the focus will be to understand the impact and the importance that vaccines have for us to fight against the SARS-COV-2 virus.
#
# To understand more about the vaccines, click at [How Vaccines Are Developed](https://www.who.int/news-room/feature-stories/detail/how-are-vaccines-developed).
#
# >**Exploratory Data Analysis:**
#
# To the Exploratory analysis start, it is first necessary to get the date for the first dose administered. Then, it is essential to carry out an exploratory analysis of the data.
#
# Researching to see if the dataset date makes sense with the beginning of when the doses started administered, we have the news link that confirms that December 2020 was when the world's population began to be vaccinated. [1st application of anti-covid vaccine a year ago with half the world immunized](https://exame.com/ciencia/1o-aplicacao-de-vacina-anti-covid-faz-um-ano-com-metade-do-mundo-imunizado/)
#
# Now let's find out if it is the same for this dataset:

# %%
# The first date of people vaccinated
df_w.loc[(df_w['people_vaccinated'] >= 1) & df_w.continent.notnull()].min()
# Out:
# iso_code                                                   ABW
# continent                                               Africa
# location                                           Afghanistan
# date                                       2020-12-01 00:00:00
# total_cases                                                  1
#                                                   ...
# human_development_index                                  0.394
# excess_mortality_cumulative_absolute                    -31505
# excess_mortality_cumulative                             -12.51
# excess_mortality                                           -45
# excess_mortality_cumulative_per_million               -1745.05
# Length: 66, dtype: object

# %% [markdown]
# * Understanding the number of people who have been vaccinated and through that confirming the vaccination started in December 2020.

# %%
# Seeing 
df_w.loc[(df_w['people_vaccinated'] == 1) & df_w.new_vaccinations.notnull(),:].head()
# Out:
#         iso_code  ... excess_mortality_cumulative_per_million
# 44987   OWID_EUR  ...                                     NaN
# 44988   OWID_EUR  ...                                     NaN
# 60025   OWID_HIC  ...                                     NaN
# 60026   OWID_HIC  ...                                     NaN
# 148079  OWID_WRL  ...                                     NaN
#
# [5 rows x 67 columns]

# %%
# The number of people which were vaccinated at november 2020
df_w_v = df_w.loc[df_w.date == '2020-11-30',"people_vaccinated"].isnull()
df_w_v
# Out:
# 280       True
# 964       True
# 1636      True
# 2308      True
# 2974      True
#           ...
# 147371    True
# 148077    True
# 148704    True
# 149354    True
# 150002    True
# Name: people_vaccinated, Length: 223, dtype: bool

# %%
# The number of people which were vaccinate at 2020-12-01

df_w_vacina = df_w.loc[df_w.date == '2020-12-01',"people_vaccinated"].notnull().sum() 
print("The vaccinations started at December first of 2020, at least", df_w_vacina  ,"individuals were vaccinated that day")
# Out:
# The vaccinations started at December first of 2020, at least 5 individuals were vaccinated that day

# %% [markdown]
# With the exploratory analysis done, now we know the vaccination started in December 2020.
# Therefore now let's plot the graphics and see how it was the impact which the vaccination has against the COVID-19

# %% [markdown]
# ### **Dashboards** for the analysis of the column `people_fully_vaccinated` for each continent:

# %%
# import the library datetime
import datetime as dt

# %%
#get a month from the column date and put this into the dataframe
df_w['month'] = df_w['date'].dt.month

# %%
# What are the entries in the continent column
df_w['continent'].unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %% [markdown]
# So for the column continent, we have data about the five continents, but if some observations, as like:
# * To the continent America, we have the North and South America
# * Has the entries of the Nan, but this happens because, when we are looking at the dataset, at the column of the `location`, they put information about the *income value*
#
#
# ---
# ### Below are the graphs for each continent
#
# The graphics show the values for the column `people_fully_vaccinated`. This variable represents the **total number of people who received all doses prescribed by the vaccination protocol**.
#
# To find the number of people who took all vaccine doses, I use the function `groupby()`.

# %%
# Total number of people who received full vaccinated for each continent

df_w.groupby(['continent']).people_fully_vaccinated.sum().sort_values(ascending = False)
# Out:
# continent
# Asia             1.043767e+11
# Europe           6.021483e+10
# North America    5.600873e+10
# South America    2.705435e+10
# Africa           4.168491e+09
# Oceania          2.053342e+09
# Name: people_fully_vaccinated, dtype: float64

# %% [markdown]
# Information about the amount of zeros for a number to be one thousand, million billion and more in this [link](https://www.matematica.pt/faq/zeros-biliao.php).

# %%
# Dashboard for the number of people fully vaccinated for each continent
sns.set_style('ticks')
fig, (ax, ax1) = plt.subplots(nrows = 1, ncols =2, figsize=(18,6))

# Remove the horizontal gap between the subplots
plt.subplots_adjust(wspace= -.50)

# Text figure
ax.text(0.0,0.900, s = 'Asia', size = 30,color = 'DarkSlateGray',weight ='bold')
ax.text(0.0, 0.40, s ='105 billions',size = 65, color = '#357599', fontweight = 'bold')
ax.text(0.0,0.250, s = ' of people fully vaccinated until December \n 8th of 2021', size = 18,color = 'DarkSlateGray', weight = 'bold')

sns.despine(left = True, bottom = True)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)

# The variable td_5 will be  the values for the data at the bar plot
pf_v = (df_w.loc[(df_w.continent == 'Asia') & df_w.continent.notnull()].sort_values(by ='people_fully_vaccinated', ascending = False)).copy()

# the barplot
pf_plot = sns.barplot(x = 'month', y = 'people_fully_vaccinated', data = pf_v, ax = ax1, color = '#357599', ci = None)

ax1.set_xlabel([], color='white')
ax1.set_ylabel([], color='white')
ax1.set_xticklabels(["Jan","Feb","Mar","Apr","May","Jun","Jul", "Aug","Sep",'Oct',"Nov",'Dec'],{'fontweight':'bold','fontsize': 12})
ax1.set_yticklabels([],color = 'white')
sns.despine(left=True, bottom=True)

plt.tight_layout()

# %%
# Dashboard for the number of people fully vaccinated for each continent
sns.set_style('ticks')
fig, (ax, ax1) = plt.subplots(nrows = 1, ncols =2, figsize=(18,6))


# Remove the horizontal gap between the subplots
plt.subplots_adjust(wspace= -.50)

# Text figure
ax.text(0.0,0.900, s = 'Europe', size = 30,color = 'DarkSlateGray',weight ='bold')
ax.text(0.0, 0.40, s ='60 billions',size = 60, color = 'Olive', fontweight = 'bold')
ax.text(0.0,0.250, s = ' of people fully vaccinated until December \n 8th of 2021', size = 18,color = 'DarkSlateGray', weight = 'bold')

sns.despine(left = True, bottom = True)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)

# The variable td_5 will be  the values for the data at the bar plot
pf_v = (df_w.loc[(df_w.continent == 'Europe') & df_w.continent.notnull()].sort_values(by ='people_fully_vaccinated', ascending = False)).copy()

# the barplot
pf_plot = sns.barplot(x = 'month', y = 'people_fully_vaccinated', data = pf_v, ax = ax1, color = 'Olive', ci = None)

ax1.set_xlabel([], color='white')
ax1.set_ylabel([], color='white')
ax1.set_xticklabels(["Jan","Feb","Mar","Apr","May","Jun","Jul", "Aug","Sep",'Oct',"Nov",'Dec'],{'fontweight':'bold','fontsize': 12})
ax1.set_yticklabels([],color = 'white')
sns.despine(left=True, bottom=True)

plt.tight_layout()

# %%
# Dashboard for the number of people fully vaccinated for each continent
sns.set_style('ticks')
fig, (ax, ax1) = plt.subplots(nrows = 1, ncols =2, figsize=(18,6))

# Remove the horizontal gap between the subplots
plt.subplots_adjust(wspace= -.50)

# Text figure
ax.text(0.0,0.900, s = 'North America', size = 30,color = 'DarkSlateGray',weight ='bold')
ax.text(0.0, 0.40, s ='55 billions',size = 65, color = '#191970', fontweight = 'bold')
ax.text(0.0,0.25, s = ' of people fully vaccinated until December \n 8th of 2021', size = 18,color = 'DarkSlateGray', weight = 'bold')

sns.despine(left = True, bottom = True)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)

# The variable td_5 will be  the values for the data at the bar plot
pf_v = (df_w.loc[(df_w.continent == 'North America') & df_w.continent.notnull()].sort_values(by ='people_fully_vaccinated', ascending = False)).copy()

# the barplot
pf_plot = sns.barplot(x = 'month', y = 'people_fully_vaccinated', data = pf_v, ax = ax1, color = '#191970', ci = None)

ax1.set_xlabel([], color='white')
ax1.set_ylabel([], color='white')
ax1.set_xticklabels(["Jan","Feb","Mar","Apr","May","Jun","Jul", "Aug","Sep",'Oct',"Nov",'Dec'],{'fontweight':'bold','fontsize': 12})
ax1.set_yticklabels([],color = 'white')
sns.despine(left=True, bottom=True)

plt.tight_layout()

# %%
# Dashboard for the number of people fully vaccinated for each continent
sns.set_style('ticks')
fig, (ax, ax1) = plt.subplots(nrows = 1, ncols =2, figsize=(18,6))

# Remove the horizontal gap between the subplots
plt.subplots_adjust(wspace= -.50)

# Text figure
ax.text(0.0,0.900, s = 'South America', size = 30,color = 'DarkSlateGray',weight ='bold')
ax.text(0.0, 0.40, s ='26 billions',size = 65, color = 'DarkOrange', fontweight = 'bold')
ax.text(0.0,0.250, s = ' of people fully vaccinated until December \n 8th of 2021', size = 18,color = 'DarkSlateGray', weight = 'bold')

sns.despine(left = True, bottom = True)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)

# The variable td_5 will be  the values for the data at the bar plot
pf_v = (df_w.loc[(df_w.continent == 'South America') & df_w.continent.notnull()].sort_values(by ='people_fully_vaccinated', ascending = False)).copy()

# the barplot
pf_plot = sns.barplot(x = 'month', y = 'people_fully_vaccinated', data = pf_v, ax = ax1, color = 'DarkOrange', ci = None)

#ax1.set_title("Total people vaccinated in South America in 2021 \n", loc = 'left', size = 20, color = 'DarkSlateGray') 
ax1.set_xlabel([], color='white')
ax1.set_ylabel([], color='white')
ax1.set_xticklabels(["Jan","Feb","Mar","Apr","May","Jun","Jul", "Aug","Sep",'Oct',"Nov",'Dec'],{'fontweight':'bold','fontsize': 12})
ax1.set_yticklabels([],color = 'white')
sns.despine(left=True, bottom=True)

plt.tight_layout()

# %%
# Dashboard for the number of people fully vaccinated for each continent
sns.set_style('ticks')
fig, (ax, ax1) = plt.subplots(nrows = 1, ncols =2, figsize=(18,6))


# Remove the horizontal gap between the subplots
plt.subplots_adjust(wspace= -.50)

# Text figure
ax.text(0.0,0.900, s = 'Africa', size = 30,color = 'DarkSlateGray',weight ='bold')
ax.text(0.0, 0.40, s ='4 billions',size = 60, color = '#4B0082', fontweight = 'bold')
ax.text(0.0,0.250, s = ' of people fully vaccinated until December \n 8th of 2021', size = 18,color = 'DarkSlateGray', weight = 'bold')

sns.despine(left = True, bottom = True)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)

# The variable td_5 will be  the values for the data at the bar plot
pf_v = (df_w.loc[(df_w.continent == 'Africa') & df_w.continent.notnull()].sort_values(by ='people_fully_vaccinated', ascending = False)).copy()

# the barplot
pf_plot = sns.barplot(x = 'month', y = 'people_fully_vaccinated', data = pf_v, ax = ax1, color = '#4B0082', ci = None)

ax1.set_xlabel([], color='white')
ax1.set_ylabel([], color='white')
ax1.set_xticklabels(["Jan","Feb","Mar","Apr","May","Jun","Jul", "Aug","Sep",'Oct',"Nov",'Dec'],{'fontweight':'bold','fontsize': 12})
ax1.set_yticklabels([],color = 'white')
sns.despine(left=True, bottom=True)

plt.tight_layout()

# %%
# Dashboard for the number of people fully vaccinated for each continent
sns.set_style('ticks')
fig, (ax, ax1) = plt.subplots(nrows = 1, ncols =2, figsize=(18,6))

# Remove the horizontal gap between the subplots
plt.subplots_adjust(wspace= -.50)

# Text figure
ax.text(0.0,0.900, s = 'Oceania', size = 30,color = 'DarkSlateGray',weight ='bold')
ax.text(0.0, 0.40, s ='2 billions',size = 60, color = '#228B22', fontweight = 'bold')
ax.text(0.0,0.250, s = ' of people fully vaccinated until December \n 8th of 2021', size = 18,color = 'DarkSlateGray', weight = 'bold')

sns.despine(left = True, bottom = True)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)

# The variable td_5 will be  the values for the data at the bar plot
pf_v = (df_w.loc[(df_w.continent == 'Oceania') & df_w.continent.notnull()].sort_values(by ='people_fully_vaccinated', ascending = False)).copy()

# the barplot
pf_plot = sns.barplot(x = 'month', y = 'people_fully_vaccinated', data = pf_v, ax = ax1, color = '#228B22', ci = None)

ax1.set_xlabel([], color='white')
ax1.set_ylabel([], color='white')
ax1.set_xticklabels(["Jan","Feb","Mar","Apr","May","Jun","Jul", "Aug","Sep",'Oct',"Nov",'Dec'],{'fontweight':'bold','fontsize': 12})
ax1.set_yticklabels([],color = 'white')
sns.despine(left=True, bottom=True)

plt.tight_layout()

# %% [markdown]
# At the wolrd we have almost 7.9 trillion of people according to [Wikipedia](https://pt.wikipedia.org/wiki/Popula%C3%A7%C3%A3o_mundial). And if we subtract this number fo the total of each continet fully vaccinated we will notice.

# %%
#Number of people fully vaccinated
x = df_w['people_fully_vaccinated'].sum()

print('The number of people fully vacinated so far is ',x)

y = 7900000000000
# The number of peoplae which aren't full vaccinated d
d = y - x

#The percentagem of this numeber
f = round(1-(d/y),3)*100


print("Now the number of people who aren't fully vaccinated ",d)
print("Only",f,"% was fully vaccinated")
print("The meaning of these values is almost all the world need to take the second dose")
# Out:
# The number of people fully vacinated so far is  1494920459504.0
# Now the number of people who aren't fully vaccinated  6405079540496.0
# Only 18.9 % was fully vaccinated
# The meaning of these values is almost all the world need to take the second dose

# %%
# Text figure
fig, ax = plt.subplots(figsize = (5,3))

# the text that will be print
ax.text(0.1, 0.50, s ='19%',size = 80, color = 'Orange', fontweight = 'bold')
ax.text(0.1,0.150, s = ' Of the people in the world \n are fully vacinated \n against COVID-19', size = 18,color = 'DarkSlateGray', weight = 'bold')

sns.despine(left=True, bottom = True)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
plt.tight_layout()

# %% [markdown]
# These analysis and graphs are some part of the work we can do using this dataset, now I am going to look at the situantion from Brazil with the data from the same dataset.

# %% [markdown]
# ## Brazil
# Moving forward to the analysis of the dataset, now I am picking Brazil to look even further at how this country is dealing against the COVID-19.
#
# ### EDA - Steps:

# %%
# Selecting Brazil
df_Brasil = df_w.loc[df_w.location == "Brazil"].copy()

# %%
# Seeing the five entries of the dataset
df_Brasil.head()
# Out:
#       iso_code      continent  ... excess_mortality_cumulative_per_million month
# 19310      BRA  South America  ...                                     NaN     2
# 19311      BRA  South America  ...                                     NaN     2
# 19312      BRA  South America  ...                                     NaN     2
# 19313      BRA  South America  ...                               32.943066     2
# 19314      BRA  South America  ...                                     NaN     3
#
# [5 rows x 68 columns]

# %%
# The types of the variables
df_Brasil.dtypes
# Out:
# iso_code                                           object
# continent                                          object
# location                                           object
# date                                       datetime64[ns]
# total_cases                                       float64
#                                                 ...
# excess_mortality_cumulative_absolute              float64
# excess_mortality_cumulative                       float64
# excess_mortality                                  float64
# excess_mortality_cumulative_per_million           float64
# month                                               int64
# Length: 68, dtype: object

# %%
# the total of Nan values for each variable
(df_Brasil.isnull().sum()/df_Brasil.shape[0]).sort_values(ascending = False)
# Out:
# icu_patients                          1.0
# handwashing_facilities                1.0
# tests_per_case                        1.0
# positive_rate                         1.0
# weekly_hosp_admissions_per_million    1.0
#                                      ...
# male_smokers                          0.0
# hospital_beds_per_thousand            0.0
# life_expectancy                       0.0
# human_development_index               0.0
# iso_code                              0.0
# Length: 68, dtype: float64

# %% [markdown]
# ###**Plots and Analysis**

# %%
# The first case of Covid-19 registed
df_Brasil.loc[df_Brasil['new_cases'] != 0.0].head(1)
# Out:
#       iso_code      continent  ... excess_mortality_cumulative_per_million month
# 19310      BRA  South America  ...                                     NaN     2
#
# [1 rows x 68 columns]

# %%
# Text figure
fig, ax = plt.subplots(figsize = (5,3))

ax.text(0.05, 0.48, s ='February 26th,',size =80, color = '#357599', fontweight = 'bold')
ax.text(0.08,0.220, s = '2020 was the date of the first COVID-19 case', size = 20,color = 'DarkSlateGray', weight = 'bold')

sns.despine(left=True, bottom = True)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   # Remove the CWD from sys.path while we load stuff.

# %%
# The first death register for Brazil 
df_Brasil.loc[df_Brasil['new_deaths'] == 1.0]
# Out:
#       iso_code      continent  ... excess_mortality_cumulative_per_million month
# 19330      BRA  South America  ...                                     NaN     3
#
# [1 rows x 68 columns]

# %%
# Text figure
fig, ax = plt.subplots(figsize = (5,3))

ax.text(0.05, 0.48, s ='March 17th,',size =80, color = 'DarkOrange', fontweight = 'bold')
ax.text(0.09,0.30, s = ' 2020 was the date of the first death by COVID-19', size = 20,color = 'DarkSlateGray', weight = 'bold')

sns.despine(left=True, bottom = True)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
plt.tight_layout()

# %% [markdown]
# > According to the dataset, these two figures show us the date of the first case and the first death attributed to COVID-19.
#
#
#
# ---
#
# **How is Brazil doing in the fight against Covid-19?**
#
# First, it is worth remembering that this date is as of December 8, 2021.
#
# The two graphs below represents the move average of the variables *new cases smoothed and new deaths smoothed*, as we saw before this variables help to understand how Brazil is fight since the beginning of the registers.

# %%
# Graph for the New cases smoothed per million

sns.set_style('ticks')
fig, ax = plt.subplots(figsize=(14,8))

# the variable for the new cases in BRazil
new_cases_brazil = (df_Brasil.loc[:, ['date', 'new_cases_smoothed_per_million']].reset_index(drop=True))

# the variable for new cases in the world
new_cases_world = (df_w.loc[df_w.location == 'World', ['date', 'new_cases_smoothed_per_million']].reset_index(drop=True))

# The line plot for each variable
sns.lineplot(x='date', y='new_cases_smoothed_per_million',
             data=new_cases_brazil, ci=None, linewidth=3, color='#357599')

sns.lineplot(x='date', y='new_cases_smoothed_per_million',
             data=new_cases_world, ci=None, linewidth=2, color='DarkSlateGray')


ax.set_title('Moving Average of the number of New Cases of COVID-19 in the Brazil and World\n\n', color='DarkSlateGray', size=20, loc='left', fontweight = 'bold')
plt.suptitle('new cases smoothed per million', x=0.170, y=0.945, color='DarkSlateGray', size=14)


# The text
ax.text(x=738140.9, y=35, s='Brazil', color='#357599', fontweight='bold', size=14)
ax.text(x=738140.9, y=80, s='World', color='DarkSlateGray',fontweight = 'bold', size=14)

ax.yaxis.set_ticklabels([' ', '0k', '50k', '100k', '150k', '200k', '250k', '300k', '350k'])

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')


sns.despine()
plt.tight_layout()

# %%
# Plot for the variable new deaths smoothed per million

sns.set_style('ticks')
fig, ax = plt.subplots(figsize=(16,8))

new_deaths_brazil = (df_Brasil.loc[:, ['date', 'new_deaths_smoothed_per_million']].reset_index(drop=True))
new_deaths_world = (df_w.loc[df_w.location == 'World', ['date', 'new_deaths_smoothed_per_million']].reset_index(drop=True))

sns.lineplot(x='date', y='new_deaths_smoothed_per_million',
             data=new_deaths_brazil, ci=None, linewidth=3, color='DarkOrange')

sns.lineplot(x='date', y='new_deaths_smoothed_per_million',
             data=new_deaths_world, ci=None, linewidth=3, color='Gray')


ax.set_title('Moving Average of the number of New Deaths of COVID-19 in the Brazil and World\n\n', color='Grey', size=20, loc='left',fontweight = 'bold')
plt.suptitle('new cases smoothed per million', x=0.159, y=0.945, color='Grey', size=14,fontweight = 'bold')

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

ax.yaxis.set_ticklabels(['', '0k', '2k', '4k', '6k', '8k', '10k', '12k', '14k'])

ax.text(x=738138, y=0.5, s='Brazil', color='DarkOrange', fontweight='bold', size=14)
ax.text(x=738138, y=1.5, s='World', color='Gray',fontweight = 'bold', size=14 )

sns.despine()
plt.tight_layout()

# %% [markdown]
# These two graphics show how was the behavior of the vírus in Brazil. Since Brazil start to the vaccine, the majority of the groups in July the number of cases started to get equal to the World.

# %%
# The number total cases for Brazil until 2021-08-12
print("Table 6 - total case until December 8th, 2021")
df_Brasil[['date','total_cases']][-1:]
# Out:
# Table 6 - total case until December 8th, 2021
#             date  total_cases
# 19961 2021-12-08   22173363.0

# %%
print("Table 7 - total deaths until December 8th, 2021")
df_Brasil[['date','total_deaths']][-1:]
# Out:
# Table 7 - total deaths until December 8th, 2021
#             date  total_deaths
# 19961 2021-12-08      616533.0

# %%
# total of people fully vaccinated
df_Brasil[['date', 'people_fully_vaccinated']][-1:]
# Out:
#             date  people_fully_vaccinated
# 19961 2021-12-08              138249795.0

# %%
# Text figure
fig, ax = plt.subplots(figsize = (5,3))

ax.text(0.0,0.900, s = 'December 08th, 2021', size = 20,color = 'DarkSlateGray',weight ='bold')
ax.text(0.08, 0.420, s ='138 million Brazilians ',size =60, color = 'DarkOrange', fontweight = 'bold')
ax.text(0.11,0.280, s = 'are fully vaccinated against the COVID-19', size = 20,color = 'DarkSlateGray', weight = 'bold')

sns.despine(left=True, bottom = True)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ### Waffle Plot - A different way to show your data
#
# According to the web page [Our World in Data](https://ourworldindata.org/covid-vaccinations?country=OWID_WRL) at the date Dec 8th, 2021, we have that approximately 55% of the world population has been vaccinated, either partial or complete, while 45% have not. As is show  at the image below:
#
# <p align=center><img src="https://github.com/heitor-eng/H_Data_Science/blob/master/Imagens/coronavirus-data-explorer.png?raw=true" width="80%"></p>
#
# We can pass the same information using the **Waffle Plot**, but here I need to use the proportion of cases, like:
# > 3.55 billion are equivalent to 44% of the data, while 811.9 million are equal to 11% and with that, we have 55% that take vaccines and the other 45% are the 4.36 billion that are not vaccines.
#
# To build the graph, I will use a sample of 100 cases here, respecting the same proportion as above for cases of people who were fully vaccinated, partially, and without having been vaccinated.

# %%
# install pywaffle
# !pip install pywaffle -q
# Out:
#      |████████████████████████████████| 565 kB 7.1 MB/s

# %%
# Calling the libraries
import matplotlib.pyplot as plt
from pywaffle import Waffle
import numpy as np

# %%
fig = plt.figure(
    FigureClass=Waffle, 
    rows=5, 
    figsize = (16,4),
    values={'Fully vaccinated': 44, 'Only partly vaccinated': 11, 'Did not take any dose': 45}, 
         title={
        'label': 'Number of people vaccinated against COVID-19\n',
        'loc': 'left',
        'fontdict': {
            'fontsize': 20
        }
    },
    colors=("OliveDrab", "DarkBlue","DarkRed"),
    icons = ['syringe','syringe','skull'],
    legend={'loc': 'upper left', 
            'bbox_to_anchor': (1, 1),
            'fontsize':20
            }, 
    icon_size=24, 
    icon_legend=True
)

fig.set_tight_layout(False)
plt.show();
# Out:
# <Waffle size 1152x288 with 1 Axes>

# %% [markdown]
# ## **Conclusion**
#
# * We notice the how fast is the way the virus Sars Covs-19 can spread into the world
# * The world didn't know how to deal with the problem at the start - beacuse of the number of cases and deaths
# * The countries with more income were able to get resoureces and track the virus more efficent than others
# * The vaccines are the way to combat the vírus
# * Only 19% of the population of the World are fully vaccinated
# * Vaccination is the best way to deal with the virus
